# %%
install.packages("twitteR")

library(twitteR)
CONSUMER_KEY = "LhS2LVBbmbvJXwFRvoNZ2fuBP"
CONSUMER_SECRET = "0Ym9QH3sDRXlVDTgxyNafMEKhaJGAZECscaPTePRZNWoaeppdB"
ACCESS_TOKEN = "829481304706146305-8pCQl9Zbm6NdPeWulXTjyPmNvwJZyg9"
ACCESS_TOKEN_SECRET = "I5w2fGH0wHN3UhdMShDiU7BzcpePVFMVS20LhAH4ZuzoC"

setup_twitter_oauth(CONSUMER_KEY,
                    CONSUMER_SECRET,
                    ACCESS_TOKEN,
                    ACCESS_TOKEN_SECRET)

tweets <- searchTwitter('#rstats', n=50)
head(tweets)
# Out:
# also installing the dependencies ‘bit’, ‘bit64’, ‘rjson’
#
# Updating HTML index of packages in '.Library'
# Making 'packages.html' ... done
# [1] "Using direct authentication"
# [[1]]
# [1] "stevenmosher: RT @hrbrmstr: theme_cap() #rstats https://t.co/OSB9UFTuPt"
#
# [[2]]
# [1] "AriLamstein: How do religion and demographics relate? #rstats #gis https://t.co/PXD0UCoJr6 https://t.co/IhaBWN5xjz"
#
# [[3]]
# [1] "hadleywickham: RT @hrbrmstr: theme_cap() #rstats https://t.co/OSB9UFTuPt"
#
# [[4]]
# [1] "RobRe62: RT @KirkDBorne: How to Install #Microsoft R Server for Windows: https://t.co/1VPRKYFL9r #Rstats #BigData #MachineLearning #DataScience http…"
#
# [[5]]
# [1] "hrbrmstr: theme_cap() #rstats https://t.co/OSB9UFTuPt"
#
# [[6]]
# [1] "frankwwu: RT @dataandme: A tour of packages: \"Deep Learning in R\" https://t.co/rxFryo4EXw #rstats #deeplearning https://t.co/qesFzpYELQ"

# %%
head(strip_retweets(tweets, strip_manual=TRUE, strip_mt=TRUE))
# Out:
# [[1]]
# [1] "AriLamstein: How do religion and demographics relate? #rstats #gis https://t.co/PXD0UCoJr6 https://t.co/IhaBWN5xjz"
#
# [[2]]
# [1] "hrbrmstr: theme_cap() #rstats https://t.co/OSB9UFTuPt"
#
# [[3]]
# [1] "SuaJorge: Great post #rstats https://t.co/kPIqeEEFb7"
#
# [[4]]
# [1] "SuaJorge: List of model types or relevant characteristics.   #rstats https://t.co/svSwnw85cg"
#
# [[5]]
# [1] "DaveRubal: Learn how to use #R with #Databases https://t.co/HEQrZstWAX #BigData #Analytics #DataScience #Rstats @BigDataU https://t.co/j1Nv4kWXYC"
#
# [[6]]
# [1] "millard_joe: Experimenting with #python and #rstats integration - managed to successfully build a species spell checking #Shiny app!"

# %%
crantastic <- getUser('crantastic')
crantastic$getDescription()
# Out:
# [1] "I like some things, and I dislike everything else."

# %%
crantastic$getFollowersCount()
# Out:
# [1] 32

# %%
crantastic$getFriends(n=5)
# Out:
# $`35985504`
# [1] "MisElizaJane"
#
# $`90472293`
# [1] "emtothea"
#
# $`30987732`
# [1] "MelanieScrofano"
#
# $`4709232802`
# [1] "WynonnaEarp"

# %%
crantastic$getFavorites(n=5)
# Out:
# [[1]]
# [1] "erictcarrasco: That \"Black lung\" line was a @Chy_Leigh joke. Loved it so much we made her keep saying it. #Supergirl #SupergirlLives #Sanvers"
#
# [[2]]
# [1] "MelanieScrofano: I shall be INSUFFERABLE when the @WynonnaEarp comic I'm co-writing with @BeauSmithRanch comes out. \"The Earp Sister… https://t.co/h0Q6XrE1dV"
#
# [[3]]
# [1] "katevoegele: just casually throwing my white gold hoops in the ring to play #GretchenWieners in this https://t.co/0l9FSGjTuD"
#
# [[4]]
# [1] "boglesthemind: Here we go, QSO - female writer, female director, female producer, female editor, female lead, female first ad #PersonOfInterest #toofemale"
#
# [[5]]
# [1] "ohnikkers: @keithkurson naw they did two shows in london and i went to both.  i made hannah fall in love with the scottish accent tho so NEXT TIME"

# %%
df <- twListToDF(tweets)
head(df)
# Out:
#   text
# 1 RT @hrbrmstr: theme_cap() #rstats https://t.co/OSB9UFTuPt
# 2 How do religion and demographics relate? #rstats #gis https://t.co/PXD0UCoJr6 https://t.co/IhaBWN5xjz
# 3 RT @hrbrmstr: theme_cap() #rstats https://t.co/OSB9UFTuPt
# 4 RT @KirkDBorne: How to Install #Microsoft R Server for Windows: https://t.co/1VPRKYFL9r #Rstats #BigData #MachineLearning #DataScience http…
# 5 theme_cap() #rstats https://t.co/OSB9UFTuPt
# 6 RT @dataandme: A tour of packages: "Deep Learning in R" https://t.co/rxFryo4EXw #rstats #deeplearning https://t.co/qesFzpYELQ
#   favorited favoriteCount replyToSN created             truncated replyToSID
# 1 FALSE     0             NA        2017-02-19 01:49:52 FALSE     NA
# 2 FALSE     0             NA        2017-02-19 01:44:53 FALSE     NA
# 3 FALSE     0             NA        2017-02-19 01:44:37 FALSE     NA
# 4 FALSE     0             NA        2017-02-19 01:41:54 FALSE     NA
# 5 FALSE     5             NA        2017-02-19 01:40:48 FALSE     NA
# 6 FALSE     0             NA        2017-02-19 01:32:02 FALSE     NA
#   id                 replyToUID
# 1 833131454208962562 NA
# 2 833130200397385728 NA
# 3 833130132340633600 NA
# 4 833129449889611776 NA
# 5 833129175129145344 NA
# 6 833126967385915392 NA
#   statusSource
# 1 <a href="http://twitter.com" rel="nofollow">Twitter Web Client</a>
# 2 <a href="http://recurpost.com" rel="nofollow">Recur Post</a>
# 3 <a href="http://tapbots.com/tweetbot" rel="nofollow">Tweetbot for iΟS</a>
# 4 <a href="http://www.robertore.it" rel="nofollow">lorelei2016</a>
# 5 <a href="http://twitter.com/download/iphone" rel="nofollow">Twitter for iPhone</a>
# 6 <a href="http://twitter.com" rel="nofollow">Twitter Web Client</a>
#   screenName    retweetCount isRetweet retweeted longitude latitude
# 1 stevenmosher   2            TRUE     FALSE     NA        NA
# 2 AriLamstein    0           FALSE     FALSE     NA        NA
# 3 hadleywickham  2            TRUE     FALSE     NA        NA
# 4 RobRe62       23            TRUE     FALSE     NA        NA
# 5 hrbrmstr       2           FALSE     FALSE     NA        NA
# 6 frankwwu       6            TRUE     FALSE     NA        NA

# %%
# Out:
#   text
# 1 RT @hrbrmstr: theme_cap() #rstats https://t.co/OSB9UFTuPt
# 2 How do religion and demographics relate? #rstats #gis https://t.co/PXD0UCoJr6 https://t.co/IhaBWN5xjz
# 3 RT @hrbrmstr: theme_cap() #rstats https://t.co/OSB9UFTuPt
# 4 RT @KirkDBorne: How to Install #Microsoft R Server for Windows: https://t.co/1VPRKYFL9r #Rstats #BigData #MachineLearning #DataScience http…
# 5 theme_cap() #rstats https://t.co/OSB9UFTuPt
# 6 RT @dataandme: A tour of packages: "Deep Learning in R" https://t.co/rxFryo4EXw #rstats #deeplearning https://t.co/qesFzpYELQ
#   favorited favoriteCount replyToSN created             truncated replyToSID
# 1 FALSE     0             NA        2017-02-19 01:49:52 FALSE     NA
# 2 FALSE     0             NA        2017-02-19 01:44:53 FALSE     NA
# 3 FALSE     0             NA        2017-02-19 01:44:37 FALSE     NA
# 4 FALSE     0             NA        2017-02-19 01:41:54 FALSE     NA
# 5 FALSE     5             NA        2017-02-19 01:40:48 FALSE     NA
# 6 FALSE     0             NA        2017-02-19 01:32:02 FALSE     NA
#   id                 replyToUID
# 1 833131454208962562 NA
# 2 833130200397385728 NA
# 3 833130132340633600 NA
# 4 833129449889611776 NA
# 5 833129175129145344 NA
# 6 833126967385915392 NA
#   statusSource
# 1 <a href="http://twitter.com" rel="nofollow">Twitter Web Client</a>
# 2 <a href="http://recurpost.com" rel="nofollow">Recur Post</a>
# 3 <a href="http://tapbots.com/tweetbot" rel="nofollow">Tweetbot for iΟS</a>
# 4 <a href="http://www.robertore.it" rel="nofollow">lorelei2016</a>
# 5 <a href="http://twitter.com/download/iphone" rel="nofollow">Twitter for iPhone</a>
# 6 <a href="http://twitter.com" rel="nofollow">Twitter Web Client</a>
#   screenName    retweetCount isRetweet retweeted longitude latitude
# 1 stevenmosher   2            TRUE     FALSE     NA        NA
# 2 AriLamstein    0           FALSE     FALSE     NA        NA
# 3 hadleywickham  2            TRUE     FALSE     NA        NA
# 4 RobRe62       23            TRUE     FALSE     NA        NA
# 5 hrbrmstr       2           FALSE     FALSE     NA        NA
# 6 frankwwu       6            TRUE     FALSE     NA        NA

# %%
install.packages("RSQLite")
library(RSQLite)

sql_lite_file = tempfile()
register_sqlite_backend(sql_lite_file)
store_tweets_db(tweets)
# Out:
# also installing the dependencies ‘memoise’, ‘plogr’
#
# Updating HTML index of packages in '.Library'
# Making 'packages.html' ... done
# [1] TRUE

# %%
from_db = load_tweets_db()
head(from_db)
# Out:
# [[1]]
# [1] "stevenmosher: RT @hrbrmstr: theme_cap() #rstats https://t.co/OSB9UFTuPt"
#
# [[2]]
# [1] "AriLamstein: How do religion and demographics relate? #rstats #gis https://t.co/PXD0UCoJr6 https://t.co/IhaBWN5xjz"
#
# [[3]]
# [1] "hadleywickham: RT @hrbrmstr: theme_cap() #rstats https://t.co/OSB9UFTuPt"
#
# [[4]]
# [1] "RobRe62: RT @KirkDBorne: How to Install #Microsoft R Server for Windows: https://t.co/1VPRKYFL9r #Rstats #BigData #MachineLearning #DataScience http…"
#
# [[5]]
# [1] "hrbrmstr: theme_cap() #rstats https://t.co/OSB9UFTuPt"
#
# [[6]]
# [1] "frankwwu: RT @dataandme: A tour of packages: \"Deep Learning in R\" https://t.co/rxFryo4EXw #rstats #deeplearning https://t.co/qesFzpYELQ"

# %%
cran_tweets <- userTimeline('cranatic')
cran_tweets[1:5]
# Out:
# [[1]]
# [1] "cranatic: Update: Bchron, BoolNet, caribou, CePa, fmri, HTSCluster, isa2, lessR, lgcp, spatstat. http://t.co/skyrajMA #rstats"
#
# [[2]]
# [1] "cranatic: New: extrafont, extrafontdb, Rttf2pt1, x12GUI. http://t.co/skyrajMA #rstats"
#
# [[3]]
# [1] "cranatic: Update: drc, RcmdrPlugin.survival, rrcov, spls. http://t.co/eEoXNifB #rstats"
#
# [[4]]
# [1] "cranatic: New: hzar. http://t.co/eEoXNifB #rstats"
#
# [[5]]
# [1] "cranatic: Update: directlabels, forensim, gdata, gWidgetstcltk, gWidgetsWWW, harvestr, rrlda, Rz, Sim.DiffProc, ... http://t.co/9JEe7K91 #rstats"

# %%
cran_tweets_large <- userTimeline('cranatic', n=100)
length(cran_tweets_large)
# Out:
# [1] 100

# %%
avail_trends = availableTrendLocations()
head(avail_trends)
# Out:
#   name      country woeid
# 1 Worldwide         1
# 2 Winnipeg  Canada  2972
# 3 Ottawa    Canada  3369
# 4 Quebec    Canada  3444
# 5 Montreal  Canada  3534
# 6 Toronto   Canada  4118

# %%
close_trends = closestTrendLocations(-42.8, -71.1)
head(close_trends)
# Out:
#   name       country woeid
# 1 Concepcion Chile   349860

# %%
trends = getTrends(2367105)
head(trends)
# Out:
#   name              url
# 1 #BritneyEverAfter http://twitter.com/search?q=%23BritneyEverAfter
# 2 #TrumpRally       http://twitter.com/search?q=%23TrumpRally
# 3 Crimson           http://twitter.com/search?q=Crimson
# 4 #NACA17           http://twitter.com/search?q=%23NACA17
# 5 #AAASmtg          http://twitter.com/search?q=%23AAASmtg
# 6 #ZGWL             http://twitter.com/search?q=%23ZGWL
#   query               woeid
# 1 %23BritneyEverAfter 2367105
# 2 %23TrumpRally       2367105
# 3 Crimson             2367105
# 4 %23NACA17           2367105
# 5 %23AAASmtg          2367105
# 6 %23ZGWL             2367105

# %%
r_tweets <- searchTwitter("#rstats", n=300)
sources <- sapply(r_tweets, function(x) x$getStatusSource())
sources <- gsub("</a>", "", sources)
sources <- strsplit(sources, ">")
sources <- sapply(sources, function(x) ifelse(length(x) > 1, x[2], x[1]))
source_table = table(sources)
pie(source_table[source_table > 10])
# Out:
# plot without title
